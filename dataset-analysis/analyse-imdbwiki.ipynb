# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import os

# %% [markdown]
# ## IMDB-Wiki
# Dataset downloaded from https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/
#
# https://github.com/imdeepmind/processed-imdb-wiki-dataset

# %%
ds_path = 'C:/0_thesis/dataset/'
csv_path = 'C:/0_thesis/dataset/'
filename_csv = 'imdbwiki-data.csv'

# %% [markdown]
# ### ONLY ONCE Create a DataFrame structure for the dataset

# %%
# https://github.com/imdeepmind/processed-imdb-wiki-dataset/blob/master/mat.py

import numpy as np
from scipy.io import loadmat
import pandas as pd
import datetime as date
from dateutil.relativedelta import relativedelta

imdb_mat = ds_path + 'imdb_crop/imdb.mat'
wiki_mat =  ds_path + 'wiki_crop/wiki.mat'

imdb_data = loadmat(imdb_mat)
wiki_data = loadmat(wiki_mat)

del imdb_mat, wiki_mat

imdb = imdb_data['imdb']
wiki = wiki_data['wiki']

imdb_photo_taken = imdb[0][0][1][0]
imdb_full_path = imdb[0][0][2][0]
imdb_gender = imdb[0][0][3][0]
#imdb_name_celebrity = imdb[0][0][4][0]
imdb_face_location = imdb[0][0][5][0]
imdb_face_score1 = imdb[0][0][6][0]
imdb_face_score2 = imdb[0][0][7][0]

wiki_photo_taken = wiki[0][0][1][0]
wiki_full_path = wiki[0][0][2][0]
wiki_gender = wiki[0][0][3][0]
#wiki_name_celebrity = wiki[0][0][4][0]
wiki_face_location = wiki[0][0][5][0]
wiki_face_score1 = wiki[0][0][6][0]
wiki_face_score2 = wiki[0][0][7][0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 imdb_mat = ds_path + 'imdb_crop/imdb.mat'
#      10 wiki_mat =  ds_path + 'wiki_crop/wiki.mat'
# ---> 12 imdb_data = loadmat(imdb_mat)
#      13 wiki_data = loadmat(wiki_mat)
#      15 del imdb_mat, wiki_mat
#
# File ~\anaconda3\envs\thesis\lib\site-packages\scipy\io\matlab\_mio.py:226, in loadmat(file_name, mdict, appendmat, **kwargs)
#     224 with _open_file_context(file_name, appendmat) as f:
#     225     MR, _ = mat_reader_factory(f, **kwargs)
# --> 226     matfile_dict = MR.get_variables(variable_names)
#     228 if mdict is not None:
#     229     mdict.update(matfile_dict)
#
# File ~\anaconda3\envs\thesis\lib\site-packages\scipy\io\matlab\_mio5.py:332, in MatFile5Reader.get_variables(self, variable_names)
#     330     continue
#     331 try:
# --> 332     res = self.read_var_array(hdr, process)
#     333 except MatReadError as err:
#     334     warnings.warn(
#     335         'Unreadable variable "%s", because "%s"' %
#     336         (name, err),
#     337         Warning, stacklevel=2)
#
# File ~\anaconda3\envs\thesis\lib\site-packages\scipy\io\matlab\_mio5.py:292, in MatFile5Reader.read_var_array(self, header, process)
#     275 def read_var_array(self, header, process=True):
#     276     ''' Read array, given `header`
#     277
#     278     Parameters
#    (...)
#     290        `process`.
#     291     '''
# --> 292     return self._matrix_reader.array_from_header(header, process)
#
# File _mio5_utils.pyx:671, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:719, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:963, in scipy.io.matlab._mio5_utils.VarReader5.read_struct()
#
# File _mio5_utils.pyx:669, in scipy.io.matlab._mio5_utils.VarReader5.read_mi_matrix()
#
# File _mio5_utils.pyx:717, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:891, in scipy.io.matlab._mio5_utils.VarReader5.read_cells()
#
# File _mio5_utils.pyx:669, in scipy.io.matlab._mio5_utils.VarReader5.read_mi_matrix()
#
# File _mio5_utils.pyx:713, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File _mio5_utils.pyx:873, in scipy.io.matlab._mio5_utils.VarReader5.read_char()
#
# KeyboardInterrupt:

# %%
# Test to see if image cropped based on face-location is consistent: NOT
#img_index = 1703 # FAIL face-location is a line or point
#img_index = 2000 # FAIL face-location is not a face
'''
img_index = 2500 # TRUE face-location is a cropped face
image = cv2.imread("./wiki_crop/"+wiki_full_path[img_index][0])

image_face_location = wiki_face_location[img_index][0]

y = int(image_face_location[0])
x = int(image_face_location[1])
h = int(image_face_location[2])
w = int(image_face_location[3])

if y != h and x != w:
    crop_image = image[x:w, y:h]
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(crop_image)
'''

# %%
imdb_path = []
wiki_path = []

imdb_filename = []
wiki_filename = []

for path in imdb_full_path:
    imdb_path.append( ds_path + '/imdb_crop/' + path[0])
    imdb_filename.append(path[0].split('/')[1])

for path in wiki_full_path:
    wiki_path.append( ds_path + '/wiki_crop/' + path[0])
    wiki_filename.append(path[0].split('/')[1])

# gender
imdb_genders = []
wiki_genders = []

## imdb
for n in range(len(imdb_gender)):
    if imdb_gender[n] == 1:
        imdb_genders.append('male')
    else:
        imdb_genders.append('female')

## wiki
for n in range(len(wiki_gender)):
    if wiki_gender[n] == 1:
        wiki_genders.append('male')
    else:
        wiki_genders.append('female')
        
# when photo is taken
imdb_dob = []
wiki_dob = []

for file in imdb_filename:
    temp = file.split('_')[2]
    temp = temp.split('-')
    if len(temp[1]) == 1:
        temp[1] = '0' + temp[1]
    if len(temp[2]) == 1:
        temp[2] = '0' + temp[2]
    if temp[1] == '00':
        temp[1] = '01'
    if temp[2] == '00':
        temp[2] = '01'
    temp
    imdb_dob.append('-'.join(temp))

for file in wiki_filename:
    wiki_dob.append(file.split('_')[1])

# %%
# age
imdb_age = []
wiki_age = []

## imdb
for i in range(len(imdb_dob)):
    try:
        d1 = date.datetime.strptime(imdb_dob[i][0:10], '%Y-%m-%d')
        d2 = date.datetime.strptime(str(imdb_photo_taken[i]), '%Y')
        rdelta = relativedelta(d2, d1)
        diff = int(rdelta.years)
    except Exception as ex:
        print(ex)
        diff = -1
    imdb_age.append(diff)

## wiki
for i in range(len(wiki_dob)):
    try:
        d1 = date.datetime.strptime(wiki_dob[i][0:10], '%Y-%m-%d')
        d2 = date.datetime.strptime(str(wiki_photo_taken[i]), '%Y')
        rdelta = relativedelta(d2, d1)
        diff = int(rdelta.years)
    except Exception as ex:
        print(ex)
        diff = -1
    wiki_age.append(diff)
# Out:
# time data '0-12-22' does not match format '%Y-%m-%d'
# time data '0-05-21' does not match format '%Y-%m-%d'
# time data '0-11-18' does not match format '%Y-%m-%d'
# time data '0-11-18' does not match format '%Y-%m-%d'
# time data '0-11-18' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-07-31' does not match format '%Y-%m-%d'
# time data '0-10-20' does not match format '%Y-%m-%d'
# time data '0-08-19' does not match format '%Y-%m-%d'
# time data '0-08-07' does not match format '%Y-%m-%d'
# time data '0-08-07' does not match format '%Y-%m-%d'
# time data '0-09-08' does not match format '%Y-%m-%d'
# time data '0-11-19' does not match format '%Y-%m-%d'
# time data '0-11-19' does not match format '%Y-%m-%d'
# time data '0-08-05' does not match format '%Y-%m-%d'
# time data '0-08-05' does not match format '%Y-%m-%d'
# time data '0-08-05' does not match format '%Y-%m-%d'
# time data '0-08-05' does not match format '%Y-%m-%d'
# time data '0-08-05' does not match format '%Y-%m-%d'
# time data '0-08-27' does not match format '%Y-%m-%d'
# time data '0-08-27' does not match format '%Y-%m-%d'
# time data '0-08-27' does not match format '%Y-%m-%d'
# time data '0-07-08' does not match format '%Y-%m-%d'
# time data '0-05-05' does not match format '%Y-%m-%d'
# time data '0-05-05' does not match format '%Y-%m-%d'
# time data '0-03-15' does not match format '%Y-%m-%d'
# time data '0-03-15' does not match format '%Y-%m-%d'
# time data '0-12-29' does not match format '%Y-%m-%d'
# time data '0-08-21' does not match format '%Y-%m-%d'
# time data '0-08-21' does not match format '%Y-%m-%d'
# time data '0-08-21' does not match format '%Y-%m-%d'
# time data '0-08-21' does not match format '%Y-%m-%d'
# time data '0-08-21' does not match format '%Y-%m-%d'
# time data '0-02-16' does not match format '%Y-%m-%d'
# time data '0-02-16' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-10-17' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-08-08' does not match format '%Y-%m-%d'
# time data '0-09-02' does not match format '%Y-%m-%d'
# time data '0-12-28' does not match format '%Y-%m-%d'
# time data '0-02-22' does not match format '%Y-%m-%d'
# time data '0-02-22' does not match format '%Y-%m-%d'
# time data '0-02-22' does not match format '%Y-%m-%d'
# time data '0-02-22' does not match format '%Y-%m-%d'
# time data '0-09-05' does not match format '%Y-%m-%d'
# time data '0-09-05' does not match format '%Y-%m-%d'
# time data '0-07-10' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-06-23' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-12-10' does not match format '%Y-%m-%d'
# time data '0-10-07' does not match format '%Y-%m-%d'
# time data '0-09-20' does not match format '%Y-%m-%d'
# time data '0-09-20' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-12-17' does not match format '%Y-%m-%d'
# time data '0-11-29' does not match format '%Y-%m-%d'
# time data '0-04-12' does not match format '%Y-%m-%d'
# time data '0-07-22' does not match format '%Y-%m-%d'
# time data '0-07-10' does not match format '%Y-%m-%d'
# time data '0-07-10' does not match format '%Y-%m-%d'
# time data '0-07-10' does not match format '%Y-%m-%d'
# time data '0-07-10' does not match format '%Y-%m-%d'
# time data '0-11-06' does not match format '%Y-%m-%d'
# time data '0-10-02' does not match format '%Y-%m-%d'
# time data '0-10-02' does not match format '%Y-%m-%d'
# time data '0-09-09' does not match format '%Y-%m-%d'
# time data '0-09-09' does not match format '%Y-%m-%d'
# time data '0-09-09' does not match format '%Y-%m-%d'
# time data '0-09-09' does not match format '%Y-%m-%d'
# time data '0-09-09' does not match format '%Y-%m-%d'
# time data '0-09-07' does not match format '%Y-%m-%d'
# time data '0-09-07' does not match format '%Y-%m-%d'
# time data '0-09-07' does not match format '%Y-%m-%d'
# time data '0-09-07' does not match format '%Y-%m-%d'
# time data '0-11-13' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '0-07-27' does not match format '%Y-%m-%d'
# time data '829-09-08' does not match format '%Y-%m-%d'
# time data '1823-12-00' does not match format '%Y-%m-%d'
# time data '1953-10-00' does not match format '%Y-%m-%d'
# time data '1984-15-03' does not match format '%Y-%m-%d'
# time data '1963-02-00' does not match format '%Y-%m-%d'
# time data '1977-04-00' does not match format '%Y-%m-%d'
# time data '1946-05-00' does not match format '%Y-%m-%d'
# time data '647-05-15' does not match format '%Y-%m-%d'
# time data '11-03-00' does not match format '%Y-%m-%d'
# time data '1980-05-00' does not match format '%Y-%m-%d'
# time data '1960-02-00' does not match format '%Y-%m-%d'
# time data '1975-03-00' does not match format '%Y-%m-%d'
# time data '1952-11-00' does not match format '%Y-%m-%d'
# time data '1974-04-00' does not match format '%Y-%m-%d'
# time data '1996-25-05' does not match format '%Y-%m-%d'
# time data '1914-02-00' does not match format '%Y-%m-%d'

# %%
cols = ['age', 'gender', 'filepath', 'filename', 'face_score1', 'face_score2']

final_imdb = np.vstack((imdb_age, imdb_genders, imdb_path, imdb_filename, imdb_face_score1, imdb_face_score2)).T
final_wiki = np.vstack((wiki_age, wiki_genders, wiki_path, wiki_filename, wiki_face_score1, wiki_face_score2)).T

final_imdb_df = pd.DataFrame(final_imdb)
final_wiki_df = pd.DataFrame(final_wiki)

final_imdb_df.columns = cols
final_wiki_df.columns = cols

df = pd.concat((final_imdb_df, final_wiki_df))

df = df[df['face_score1'] != '-inf']
df = df[df['face_score2'] == 'nan']

df = df.drop(['face_score1', 'face_score2'], axis=1)

df['age'] = df['age'].astype('int')
df = df.drop(df[df.age < 0].index)

df = df.sample(frac=1)

df.to_csv(csv_path + filename_csv, index=False)

# %% [markdown]
# ### Analysis: observe the balance in the dataset of gender, age

# %%
df = pd.read_csv(csv_path + filename_csv)
n_tot_images = df.shape[0]
n_tot_images
#df.head()
# Out:
# 224624

# %%
df['age'] = df['age'].astype('int')
df.age.max()
# Out:
# 429

# %%
df.columns
# Out:
# Index(['age', 'gender', 'filepath', 'filename', 'age-group'], dtype='object')

# %% [markdown]
# ### Gender

# %%
df['gender'].value_counts().plot.pie(autopct="%1.1f%%", labels=['male', 'female'])
plt.legend()

# %% [markdown]
# ### Age

# %%
plt.hist(df['age'], range(140))
plt.title('Age Distribution')
plt.show()

# %%
from age_groups import *

ranges = AgeGroups().getRanges()

print("The percentage of images to the total in ")
count_age_ranges = []
for r in ranges:
    count_age_range = sum([len(df[df.age == j]) for j in r])
    count_age_ranges.append(count_age_range)
    print(r, "years:", round(count_age_range/n_tot_images*100,2))
# Out:
# The percentage of images to the total in
# range(0, 3) years: 0.05
# range(3, 13) years: 1.37
# range(13, 20) years: 5.81
# range(20, 30) years: 27.7
# range(30, 40) years: 30.32
# range(40, 50) years: 18.78
# range(50, 60) years: 9.08
# range(60, 70) years: 4.46
# range(70, 80) years: 1.78
# range(80, 90) years: 0.53
# range(90, 100) years: 0.09
# range(100, 117) years: 0.01

# %%
# Show a plot with the age distribution
ranges_axis = []

for r in ranges:
    ranges_axis.append("("+str(min(r))+", "+str(max(r))+")")

x_pos = np.arange(len(ranges))
fig = plt.figure(dpi=100, figsize=(20, 7)) 
plt.bar(x_pos, count_age_ranges, align='center')
plt.xticks(x_pos, ranges_axis)
plt.ylabel('Number of images')
plt.xlabel('Age groups')
plt.title('Number of images in each group')
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(9):
    sample = df.loc[i]
    plt.subplot(3,3,i+1)
    plt.axis('off')
    plt.title('%i, %s' % (sample.age, sample.gender))
    plt.imshow(Image.open(sample.filepath))
